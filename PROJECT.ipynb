# %% [markdown]
# <a href="https://colab.research.google.com/github/ombelote/Small_Projects-or-Assignments/blob/main/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Malware analysis Using 1-D CNN

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization,Activation
from tensorflow.keras.layers import Conv2D,MaxPool1D
from tensorflow.keras.optimizers import Adam
print("Tensorflow Version is: ",tf.__version__)
# Out:
# Tensorflow Version is:  1.14.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("dataset_malware.csv")
data.head()
# Out:
#                                           Unnamed: 0  AddressOfEntryPoint  \
# 0  0004cec68fdb95507c6161d84e4965db60f997a679ce20...           1073962461
# 1  0024eec62931670946abd4240d38127e23b4c0c9321de4...                37296
# 2  00a02d154e7389d3a5fe572e9800f1628e74b8aabe4270...           1073916548
# 3  00aac566d9664b844e5d7ae641c58131ce59deced31223...                51656
# 4  00cb557ec3c36d07f27e264dd6bffb6c858a3d9568878d...                39104
#
#    DebugRVA  DebugSize    Dll  ExportRVA  ExportSize  IATRVA   ImageBase  \
# 0         0          0  32768          0           0  155648     4194304
# 1     24720         28      0          0           0   24576       65536
# 2         0          0  32768          0           0  114688  5368709120
# 3      5424         28  32832          0           0    4096  4294967296
# 4      9360         28  32768          0           0    8192  4294967296
#
#    ImageVersion  ... LinkerVersion NumberOfImportDLL  NumberOfImportFunctions  \
# ...

# %%
data1=pd.read_csv("dataset_clean.csv")
data1.head()
# Out:
#                                           Unnamed: 0  AddressOfEntryPoint  \
# 0  00070b0d4cb037c40d5d2464f92841aeb9ad863472bf95...                21704
# 1  00696555cbf6db83af785f8acb2270b9411cfc75e7f6d3...                29424
# 2  007247436f041ca59c5ee0e8636c668c2a43376aeb8cfa...               227872
# 3  007bdab757d03d94e60c9b1e3eec13b07562705c514992...                10656
# 4  008fa2b9697f9a173e40572face100410e51975e34a5ce...               152696
#
#    DebugRVA  DebugSize    Dll  ExportRVA  ExportSize   IATRVA   ImageBase  \
# 0      4880         28      0          0           0     4096     4194304
# 1      4256         28  49472      32576         163    36864     4194304
# 2     82400         84  49472          0           0  3522560     4194304
# 3      4320         28  49472          0           0    20480     4194304
# 4      4224         28  33120          0           0   200704  5368709120
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# AddressOfEntryPoint         0
# DebugRVA                    0
# DebugSize                   0
# Dll                         0
# ExportRVA                   0
# ExportSize                  0
# IATRVA                      0
# ImageBase                   0
# ImageVersion                0
# ImportedDLL                 0
# ImportedFunctions           0
# LinkerVersion               0
# NumberOfImportDLL           0
# NumberOfImportFunctions     0
# NumberOfSections            0
# OSVersion                   0
# ResSize                     0
# SectionNames               97
# StackReserveSize            0
# filename                    0
# Malware                     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                  0
# AddressOfEntryPoint         0
# DebugRVA                    0
# DebugSize                   0
# Dll                         0
# ExportRVA                   0
# ExportSize                  0
# IATRVA                      0
# ImageBase                   0
# ImageVersion                0
# ImportedDLL                 0
# ImportedFunctions           0
# LinkerVersion               0
# NumberOfImportDLL           0
# NumberOfImportFunctions     0
# NumberOfSections            0
# OSVersion                   0
# ResSize                     0
# SectionNames               97
# StackReserveSize            0
# filename                    0
# Malware                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               995 non-null    object
#  1   AddressOfEntryPoint      995 non-null    int64
#  2   DebugRVA                 995 non-null    int64
#  3   DebugSize                995 non-null    int64
#  4   Dll                      995 non-null    int64
#  5   ExportRVA                995 non-null    int64
#  6   ExportSize               995 non-null    int64
#  7   IATRVA                   995 non-null    int64
#  8   ImageBase                995 non-null    int64
#  9   ImageVersion             995 non-null    int64
#  10  ImportedDLL              995 non-null    object
#  11  ImportedFunctions        995 non-null    object
#  12  LinkerVersion            995 non-null    int64
#  13  NumberOfImportDLL        995 non-null    int64
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1297 non-null   object
#  1   AddressOfEntryPoint      1297 non-null   int64
#  2   DebugRVA                 1297 non-null   int64
#  3   DebugSize                1297 non-null   int64
#  4   Dll                      1297 non-null   int64
#  5   ExportRVA                1297 non-null   int64
#  6   ExportSize               1297 non-null   int64
#  7   IATRVA                   1297 non-null   int64
#  8   ImageBase                1297 non-null   int64
#  9   ImageVersion             1297 non-null   int64
#  10  ImportedDLL              1297 non-null   object
#  11  ImportedFunctions        1297 non-null   object
#  12  LinkerVersion            1297 non-null   int64
#  13  NumberOfImportDLL        1297 non-null   int64
# ...

# %%
data.shape
# Out:
# (995, 22)

# %%
data1.shape
# Out:
# (1297, 22)

# %%
data1=data1.sample(data.shape[0])

# %%
data1.shape
# Out:
# (995, 22)

# %%
# frames = [data,data1]
# merged_output= pd.concat(frames)

# %%
merged_output.head()
# Out:
#    AddressOfEntryPoint  DebugRVA  DebugSize    Dll  ExportRVA  ExportSize  \
# 0           1073962461         0          0  32768          0           0
# 1                37296     24720         28      0          0           0
# 2           1073916548         0          0  32768          0           0
# 3                51656      5424         28  32832          0           0
# 4                39104      9360         28  32768          0           0
#
#    IATRVA   ImageBase  ImageVersion  LinkerVersion  NumberOfImportDLL  \
# 0  155648     4194304             0              8                 14
# 1   24576       65536             6              9                  2
# 2  114688  5368709120             0              9                  9
# 3    4096  4294967296             6              9                  7
# 4    8192  4294967296             5              8                  0
#
#    NumberOfImportFunctions  NumberOfSections  OSVersion  ResSize  \
# ...

# %%
merged_output.tail()
# Out:
#       AddressOfEntryPoint  DebugRVA  DebugSize    Dll  ExportRVA  ExportSize  \
# 1030               120081    214064         56  33088          0           0
# 324                  5872      4176         28  49472          0           0
# 529                 43507         0          0  33088          0           0
# 421                  8323      4384         28  32768          0           0
# 858                 12538         0          0  32768          0           0
#
#       IATRVA  ImageBase  ImageVersion  LinkerVersion  NumberOfImportDLL  \
# 1030  212992    4194304             0             12                  6
# 324    12288    4194304             6             11                  4
# 529   110592    4194304             0             12                  6
# 421     4096   16777216             5              7                  7
# 858    28672    4194304             6              6                  8
#
# ...

# %%
merged_output.shape
# Out:
# (1990, 17)

# %%
merged_output["Malware"].value_counts()
# Out:
# 1    995
# 0    995
# Name: Malware, dtype: int64

# %%
# # merged_output= merged_output.drop('Unnamed: 0',axis=1)
# merged_output= merged_output.drop('ImportedDLL',axis=1)
# merged_output= merged_output.drop('ImportedFunctions',axis=1)
# merged_output= merged_output.drop('SectionNames',axis=1)
# merged_output= merged_output.drop('filename',axis=1)

# %%
merged_output.loc[new_ids, core_cols] = df_small.loc[new_ids, core_cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-e594abfe52f8> in <module>
# ----> 1 merged_output.loc[new_ids, core_cols] = df_small.loc[new_ids, core_cols]
#
# NameError: name 'df_small' is not defined

# %%
merged_output.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1990 entries, 0 to 858
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AddressOfEntryPoint      1990 non-null   int64
#  1   DebugRVA                 1990 non-null   int64
#  2   DebugSize                1990 non-null   int64
#  3   Dll                      1990 non-null   int64
#  4   ExportRVA                1990 non-null   int64
#  5   ExportSize               1990 non-null   int64
#  6   IATRVA                   1990 non-null   int64
#  7   ImageBase                1990 non-null   int64
#  8   ImageVersion             1990 non-null   int64
#  9   LinkerVersion            1990 non-null   int64
#  10  NumberOfImportDLL        1990 non-null   int64
#  11  NumberOfImportFunctions  1990 non-null   int64
#  12  NumberOfSections         1990 non-null   int64
#  13  OSVersion                1990 non-null   int64
# ...

# %%
X= merged_output.drop('Malware',axis=1)
y=merged_output['Malware']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0,stratify=y)

# %%
X_train.shape,X_test.shape
# Out:
# ((1592, 16), (398, 16))

# %%
X_train
# Out:
#       AddressOfEntryPoint  DebugRVA  DebugSize    Dll  ExportRVA  ExportSize  \
# 332                 36964     24768         28      0          0           0
# 605                 50000      5440         28  33088          0           0
# 301                  6768      4576         56  49472          0           0
# 110                  5664      4176         28  49472          0           0
# 1037                20288      4240         28  49472          0           0
# ...                   ...       ...        ...    ...        ...         ...
# 1289                94144    120688         28  33088     167424          78
# 443                 10556      4160         28  33120          0           0
# 1204                36102     35708         28  34144          0           0
# 615                     0         0          0  34112          0           0
# 1024                 8160     12816         28  33088          0           0
#
# ...

# %%
scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.fit_transform(X_test)

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],1)

# %%
X_test.shape
X_train.shape
# Out:
# (1592, 16, 1)

# %%
epochs=20
model = Sequential()
model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu',input_shape= X_train[0].shape))
model.add(keras.layers.BatchNormalization())
model.add(Dropout(0.2))
print(X_train[0].shape)
model.add(keras.layers.Conv1D(64,3,padding='same',activation='relu'))
model.add(keras.layers.BatchNormalization())
model.add(Dropout(0.5))
print(X_train[0].shape)
model.add(Flatten())
#model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu'))
#model.add(Dropout(0.5))

model.add(Dense(1,activation="sigmoid"))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# (16, 1)
# (16, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d (Conv1D)              (None, 16, 32)            128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 32)            128
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 32)            0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 16, 64)            6208
# ...

# %%
model.compile(optimizer=Adam(lr=0.00001),loss= 'binary_crossentropy',metrics=['accuracy'])

# %%
history =model.fit(X_train,y_train,epochs=100,validation_data=(X_test,y_test),verbose=1)
# Out:
# Train on 1592 samples, validate on 398 samples
# Epoch 1/100
# 1592/1592 [==============================] - 1s 546us/sample - loss: 0.1078 - acc: 0.9592 - val_loss: 0.2220 - val_acc: 0.9095
# Epoch 2/100
# 1592/1592 [==============================] - 0s 250us/sample - loss: 0.1021 - acc: 0.9642 - val_loss: 0.2220 - val_acc: 0.9070
# Epoch 3/100
# 1592/1592 [==============================] - 0s 260us/sample - loss: 0.1104 - acc: 0.9585 - val_loss: 0.2229 - val_acc: 0.9070
# Epoch 4/100
# 1592/1592 [==============================] - 0s 304us/sample - loss: 0.1032 - acc: 0.9642 - val_loss: 0.2225 - val_acc: 0.9070
# Epoch 5/100
# 1592/1592 [==============================] - 0s 262us/sample - loss: 0.1135 - acc: 0.9592 - val_loss: 0.2229 - val_acc: 0.9095
# Epoch 6/100
# 1592/1592 [==============================] - 1s 335us/sample - loss: 0.1000 - acc: 0.9636 - val_loss: 0.2247 - val_acc: 0.9045
# Epoch 7/100
# ...

# %%
# epochs=20
# model = Sequential()
# model.add(keras.layers.Conv1D(32,1,padding='same',activation='relu',input_shape= X_train[0].shape))
# model.add(keras.layers.BatchNormalization())
# model.add(Dropout(0.2))

# model.add(keras.layers.Conv1D(64,1,padding='same',activation='relu'))
# model.add(keras.layers.BatchNormalization())
# model.add(Dropout(0.5))
# print(X_train[0].shape)
# model.add(Flatten())
# # model.add(keras.layers.Conv1D(32,1,padding='same',activation='relu'))
# # model.add(Dropout(0.5))

# model.add(Dense(1,activation="sigmoid"))
# model.summary()
